# %% [markdown]
# ## Homework
#
# > Note: sometimes your answer doesn't match one of
# > the options exactly. That's fine.
# > Select the option that's closest to your solution.
# > If it's exactly in between two options, select the higher value.
#
#
# ### Dataset
#
# In this homework, we continue using the fuel efficiency dataset.
# Download it from <a href='https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv'>here</a>.
#
# You can do it with wget:
#
# ```bash
# wget https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv
# ```
#
# The goal of this homework is to create a regression model for predicting the car fuel efficiency (column `'fuel_efficiency_mpg'`).
#
#
#
# ### Preparing the dataset
#
# Preparation:
#
# * Fill missing values with zeros.
# * Do train/validation/test split with 60%/20%/20% distribution.
# * Use the `train_test_split` function and set the `random_state` parameter to 1.
# * Use `DictVectorizer(sparse=True)` to turn the dataframes into matrices.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer

car_fuel_eff_url = 'https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv'
df = pd.read_csv(car_fuel_eff_url)

# %%
# Filling "na"s with 0s
df = df.fillna(0)

# %%
df_full_train, df_test = train_test_split(df, test_size=0.2, random_state=1)
df_train, df_val = train_test_split(df_full_train, test_size=0.25, random_state=1)

df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

y_train = df_train['fuel_efficiency_mpg']
y_val = df_val['fuel_efficiency_mpg']
y_test = df_test['fuel_efficiency_mpg']

df_train.drop(columns=['fuel_efficiency_mpg'], inplace=True)
df_val.drop(columns=['fuel_efficiency_mpg'], inplace=True)
df_test.drop(columns=['fuel_efficiency_mpg'], inplace=True)

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
# prepare data for dict vectorizer
train_dicts = df_train.to_dict(orient='records')
val_dicts = df_val.to_dict(orient='records')
test_dicts = df_test.to_dict(orient='records')

# init dict vectorizer
dv = DictVectorizer(sparse=True)

dv.fit(train_dicts)

# encode df_train
X_train = dv.transform(train_dicts)
X_val = dv.transform(val_dicts)
X_test = dv.transform(test_dicts)

# %% [markdown]
# ## Question 1
#
# Let's train a decision tree regressor to predict the `fuel_efficiency_mpg` variable.
#
# * Train a model with `max_depth=1`.
#
#
# Which feature is used for splitting the data?
#
#
# * `'vehicle_weight'`
# * `'model_year'`
# * `'origin'`
# * `'fuel_type'`

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor(max_depth=1)

dtr.fit(X=X_train, y=y_train)
# Out:
# DecisionTreeRegressor(max_depth=1)

# %%
dv.get_feature_names_out()
# Out:
# array(['acceleration', 'drivetrain=All-wheel drive',
#        'drivetrain=Front-wheel drive', 'engine_displacement',
#        'fuel_type=Diesel', 'fuel_type=Gasoline', 'horsepower',
#        'model_year', 'num_cylinders', 'num_doors', 'origin=Asia',
#        'origin=Europe', 'origin=USA', 'vehicle_weight'], dtype=object)

# %%
features_df = pd.DataFrame(list(zip(dv.get_feature_names_out(), dtr.feature_importances_)), columns=['feature', 'importance'])
features_df.sort_values(by='importance', ascending=False, inplace=True)
features_df.head(1)
# Out:
#            feature  importance
# 13  vehicle_weight         1.0

# %% [markdown]
# ## Question 2
#
# Train a random forest regressor with these parameters:
#
# * `n_estimators=10`
# * `random_state=1`
# * `n_jobs=-1` (optional - to make training faster)
#
#
# What's the RMSE of this model on the validation data?
#
# * 0.045
# * 0.45
# * 4.5
# * 45.0

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rfr = RandomForestRegressor(n_estimators=10, random_state=1)

# train model
rfr.fit(X_train, y=y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=1)

# %%
from sklearn.metrics import root_mean_squared_error

y_pred = rfr.predict(X_val)
root_mean_squared_error(y_true=y_val, y_pred=y_pred)
# Out:
# 0.4595777223092726

# %% [markdown]
# ## Question 3
#
# Now let's experiment with the `n_estimators` parameter
#
# * Try different values of this parameter from 10 to 200 with step 10.
# * Set `random_state` to `1`.
# * Evaluate the model on the validation dataset.
#
#
# After which value of `n_estimators` does RMSE stop improving?
# Consider 3 decimal places for calculating the answer.
#
# - 10
# - 25
# - 80
# - 200
#
# If it doesn't stop improving, use the latest iteration number in
# your answer.

# %%
import numpy as np

# %%
n_estimators = np.arange(10, 210, step=10)

RANDOM_STATE = 1

n_est_rmse = []

for n_est in n_estimators:
    
    rfr_worker = RandomForestRegressor(n_estimators=n_est, random_state=RANDOM_STATE, n_jobs=-1)
    rfr_worker.fit(X=X_train, y=y_train)

    y_pred = rfr_worker.predict(X_val)
    rmse = root_mean_squared_error(y_true=y_val, y_pred=y_pred)

    n_est_rmse.append((n_est, round(rmse, 3)))


n_est_rmse
# Out:
# [(np.int64(10), 0.46),
#  (np.int64(20), 0.454),
#  (np.int64(30), 0.452),
#  (np.int64(40), 0.449),
#  (np.int64(50), 0.447),
#  (np.int64(60), 0.445),
#  (np.int64(70), 0.445),
#  (np.int64(80), 0.445),
#  (np.int64(90), 0.445),
#  (np.int64(100), 0.445),
#  (np.int64(110), 0.444),
#  (np.int64(120), 0.444),
#  (np.int64(130), 0.444),
#  (np.int64(140), 0.443),
#  (np.int64(150), 0.443),
#  (np.int64(160), 0.443),
#  (np.int64(170), 0.443),
#  (np.int64(180), 0.442),
#  (np.int64(190), 0.442),
#  (np.int64(200), 0.442)]

# %% [markdown]
# ### visually after n_est = 60 the RMSE looks like not imporving significantly

# %%
from matplotlib import pyplot as plt

df_n_est_rmse = pd.DataFrame(n_est_rmse, columns=['n_est', 'rmse'])

plt.plot(df_n_est_rmse.n_est, df_n_est_rmse.rmse)

# %% [markdown]
# ## Question 4
#
# Let's select the best `max_depth`:
#
# * Try different values of `max_depth`: `[10, 15, 20, 25]`
# * For each of these values,
#   * try different values of `n_estimators` from 10 till 200 (with step 10)
#   * calculate the mean RMSE
# * Fix the random seed: `random_state=1`
#
#
# What's the best `max_depth`, using the mean RMSE?
#
# * 10
# * 15
# * 20
# * 25

# %%
max_depths = [10, 15, 20, 25]

# dict to keep (max_depth, n_estimators, rmse)
md_n_est_md_rmse = []

for md in max_depths:
    for n_est_md in n_estimators:
        rfr_md = RandomForestRegressor(
            n_estimators=n_est_md,
            max_depth=md,
            random_state=RANDOM_STATE)

        rfr_md.fit(X_train, y_train)

        y_pred = rfr_md.predict(X_val)
        rmse_md = root_mean_squared_error(y_val, y_pred)

        md_n_est_md_rmse.append((md, n_est_md, rmse_md))

md_n_est_md_rmse
# Out:
# [(10, np.int64(10), 0.4502486597058524),
#  (10, np.int64(20), 0.44685703362920204),
#  (10, np.int64(30), 0.44547396459413735),
#  (10, np.int64(40), 0.4430673112962584),
#  (10, np.int64(50), 0.44195668621793566),
#  (10, np.int64(60), 0.4416730330613033),
#  (10, np.int64(70), 0.4412975503694072),
#  (10, np.int64(80), 0.4414352350072895),
#  (10, np.int64(90), 0.4415215165581006),
#  (10, np.int64(100), 0.44121699790710184),
#  (10, np.int64(110), 0.440526227247825),
#  (10, np.int64(120), 0.4407083659646053),
#  (10, np.int64(130), 0.440629500094825),
#  (10, np.int64(140), 0.44033941277349004),
#  (10, np.int64(150), 0.43994270355172643),
#  (10, np.int64(160), 0.43979740503833187),
#  (10, np.int64(170), 0.4400174394744503),
#  (10, np.int64(180), 0.4397488696817066),
#  (10, np.int64(190), 0.43985420021815086),
#  (10, np.int64(200), 0.43984510625501455),
#  (15, np.int64(10), 0.4576238478625812),
#  (15, np.int64(20), 0.45307187353797973),
#  (15, np.int64(30), 0.4508686966214543),
#  (15, np.int64(40), 0.448609348897959),
#  (15, np.int64(50), 0.44631807691848663),
#  (15, np.int64(60), 0.4452920607552113),
#  (15, np.int64(70), 0.4446057004494103),
#  (15, np.int64(80), 0.44456685304987675),
#  (15, np.int64(90), 0.44457621900521277),
#  (15, np.int64(100), 0.4443410830874172),
#  (15, np.int64(110), 0.44347884734275095),
#  (15, np.int64(120), 0.4437341465213442),
#  (15, np.int64(130), 0.4435457361621003),
#  (15, np.int64(140), 0.4431627041644266),
#  (15, np.int64(150), 0.4427315468888105),
#  (15, np.int64(160), 0.44250726673675567),
#  (15, np.int64(170), 0.44255661607337693),
#  (15, np.int64(180), 0.44206061032158256),
#  (15, np.int64(190), 0.4423360720657838),
#  (15, np.int64(200), 0.4423455848136944),
#  (20, np.int64(10), 0.45873868286340574),
#  (20, np.int64(20), 0.45402938825821765),
#  (20, np.int64(30), 0.4519817374335399),
#  (20, np.int64(40), 0.4493145647994632),
#  (20, np.int64(50), 0.44731243215557775),
#  (20, np.int64(60), 0.4461330365463001),
#  (20, np.int64(70), 0.4454851596180039),
#  (20, np.int64(80), 0.44584775036905105),
#  (20, np.int64(90), 0.4457934599727934),
#  (20, np.int64(100), 0.4453065539170869),
#  (20, np.int64(110), 0.4441990134854148),
#  (20, np.int64(120), 0.44449721373525425),
#  (20, np.int64(130), 0.44412053479755),
#  (20, np.int64(140), 0.4437643431532225),
#  (20, np.int64(150), 0.4433079818804983),
#  (20, np.int64(160), 0.4431783861339574),
#  (20, np.int64(170), 0.44332086658708497),
#  (20, np.int64(180), 0.4428497148223701),
#  (20, np.int64(190), 0.4429726771579769),
#  (20, np.int64(200), 0.4429049871977397),
#  (25, np.int64(10), 0.4594545167806103),
#  (25, np.int64(20), 0.4539205415012965),
#  (25, np.int64(30), 0.45208344969042563),
#  (25, np.int64(40), 0.44898610923906707),
#  (25, np.int64(50), 0.4469006499482943),
#  (25, np.int64(60), 0.4457028475499256),
#  (25, np.int64(70), 0.4452809922204436),
#  (25, np.int64(80), 0.445151153356735),
#  (25, np.int64(90), 0.4450113589211353),
#  (25, np.int64(100), 0.4447779288562034),
#  (25, np.int64(110), 0.4437332511477202),
#  (25, np.int64(120), 0.4440069394584261),
#  (25, np.int64(130), 0.44379062537075326),
#  (25, np.int64(140), 0.4433952938220913),
#  (25, np.int64(150), 0.4429370681493314),
#  (25, np.int64(160), 0.4427998675203279),
#  (25, np.int64(170), 0.44284338959963665),
#  (25, np.int64(180), 0.44240930602181167),
#  (25, np.int64(190), 0.44253402552174015),
#  (25, np.int64(200), 0.44247941055635037)]

# %%
import seaborn as sns

df_md_n_est_rmse = pd.DataFrame(md_n_est_md_rmse, columns=['max_depth', 'n_estimators', 'rmse'])

df_pivot = df_md_n_est_rmse.pivot(index='n_estimators', columns='max_depth', values='rmse').round(3)

sns.heatmap(df_pivot, annot=True, fmt='.3f')

# %%
df_pivot.round(3)
# Out:
# max_depth        10     15     20     25
# n_estimators
# 10            0.450  0.458  0.459  0.459
# 20            0.447  0.453  0.454  0.454
# 30            0.445  0.451  0.452  0.452
# 40            0.443  0.449  0.449  0.449
# 50            0.442  0.446  0.447  0.447
# 60            0.442  0.445  0.446  0.446
# 70            0.441  0.445  0.445  0.445
# 80            0.441  0.445  0.446  0.445
# 90            0.442  0.445  0.446  0.445
# 100           0.441  0.444  0.445  0.445
# 110           0.441  0.443  0.444  0.444
# 120           0.441  0.444  0.444  0.444
# 130           0.441  0.444  0.444  0.444
# 140           0.440  0.443  0.444  0.443
# 150           0.440  0.443  0.443  0.443
# 160           0.440  0.443  0.443  0.443
# 170           0.440  0.443  0.443  0.443
# 180           0.440  0.442  0.443  0.442
# 190           0.440  0.442  0.443  0.443
# 200           0.440  0.442  0.443  0.442

# %% [markdown]
# ### It seems that max depth of 10 gives the smallest RMSE

# %% [markdown]
# # Question 5
#
# We can extract feature importance information from tree-based models.
#
# At each step of the decision tree learning algorithm, it finds the best split.
# When doing it, we can calculate "gain" - the reduction in impurity before and after the split.
# This gain is quite useful in understanding what are the important features for tree-based models.
#
# In Scikit-Learn, tree-based models contain this information in the
# [`feature_importances_`](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn.ensemble.RandomForestRegressor.feature_importances_)
# field.
#
# For this homework question, we'll find the most important feature:
#
# * Train the model with these parameters:
#   * `n_estimators=10`,
#   * `max_depth=20`,
#   * `random_state=1`,
#   * `n_jobs=-1` (optional)
# * Get the feature importance information from this model
#
#
# What's the most important feature (among these 4)?
#
# * `vehicle_weight`
# *	`horsepower`
# * `acceleration`
# * `engine_displacement`

# %%
rfr_md20 = RandomForestRegressor(n_estimators=10, max_depth=20, random_state=1)

rfr_md20.fit(X_train, y_train)

feat_imp = pd.DataFrame(
    list(
        zip(dv.get_feature_names_out(), rfr_md20.feature_importances_)
        ),
    columns=['feature_name', 'importance']
    )

feat_imp.sort_values('importance', ascending=False)
# Out:
#                     feature_name  importance
# 13                vehicle_weight    0.959150
# 6                     horsepower    0.015998
# 0                   acceleration    0.011480
# 3            engine_displacement    0.003273
# 7                     model_year    0.003212
# 8                  num_cylinders    0.002343
# 9                      num_doors    0.001635
# 12                    origin=USA    0.000540
# 11                 origin=Europe    0.000519
# 10                   origin=Asia    0.000462
# 5             fuel_type=Gasoline    0.000360
# 1     drivetrain=All-wheel drive    0.000357
# 2   drivetrain=Front-wheel drive    0.000345
# 4               fuel_type=Diesel    0.000325

# %% [markdown]
# ## Question 6
#
# Now let's train an XGBoost model! For this question, we'll tune the `eta` parameter:
#
# * Install XGBoost
# * Create DMatrix for train and validation
# * Create a watchlist
# * Train a model with these parameters for 100 rounds:
#
# ```
# xgb_params = {
#     'eta': 0.3,
#     'max_depth': 6,
#     'min_child_weight': 1,
#
#     'objective': 'reg:squarederror',
#     'nthread': 8,
#
#     'seed': 1,
#     'verbosity': 1,
# }
# ```
#
# Now change `eta` from `0.3` to `0.1`.
#
# Which eta leads to the best RMSE score on the validation dataset?
#
# * 0.3
# * 0.1
# * Both give equal value

# %%
import xgboost as xgb

# %%
features = list(dv.get_feature_names_out())

dtrain = xgb.DMatrix(data=X_train, label=y_train, feature_names=features)
dval = xgb.DMatrix(data=X_val, label=y_val, feature_names=features)

# %%
watchlist = [(dtrain, 'train'), (dval, 'val')]

# %%
xgb_params = {
    'eta': 0.3,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'reg:squarederror',
    'nthread': 24,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(params=xgb_params, dtrain=dtrain, num_boost_round=200,
                  evals=watchlist)
# Out:
# [0]	train-rmse:1.81393	val-rmse:1.85444
# [1]	train-rmse:1.31919	val-rmse:1.35353
# [2]	train-rmse:0.98120	val-rmse:1.01316
# [3]	train-rmse:0.75443	val-rmse:0.78667
# [4]	train-rmse:0.60680	val-rmse:0.64318
# [5]	train-rmse:0.51381	val-rmse:0.55664
# [6]	train-rmse:0.45470	val-rmse:0.50321
# [7]	train-rmse:0.41881	val-rmse:0.47254
# [8]	train-rmse:0.39534	val-rmse:0.45509
# [9]	train-rmse:0.38038	val-rmse:0.44564
# [10]	train-rmse:0.37115	val-rmse:0.43896
# [11]	train-rmse:0.36361	val-rmse:0.43594
# [12]	train-rmse:0.35850	val-rmse:0.43558
# [13]	train-rmse:0.35365	val-rmse:0.43394
# [14]	train-rmse:0.35025	val-rmse:0.43349
# [15]	train-rmse:0.34666	val-rmse:0.43362
# [16]	train-rmse:0.34459	val-rmse:0.43378
# [17]	train-rmse:0.34128	val-rmse:0.43405
# [18]	train-rmse:0.33822	val-rmse:0.43391
# [19]	train-rmse:0.33709	val-rmse:0.43374
# [20]	train-rmse:0.33553	val-rmse:0.43376
# [21]	train-rmse:0.33243	val-rmse:0.43453
# [22]	train-rmse:0.33031	val-rmse:0.43510
# [23]	train-rmse:0.32815	val-rmse:0.43601
# [24]	train-rmse:0.32670	val-rmse:0.43592
# [25]	train-rmse:0.32268	val-rmse:0.43683
# [26]	train-rmse:0.32085	val-rmse:0.43678
# [27]	train-rmse:0.32035	val-rmse:0.43681
# [28]	train-rmse:0.31879	val-rmse:0.43719
# [29]	train-rmse:0.31653	val-rmse:0.43739
# [30]	train-rmse:0.31475	val-rmse:0.43752
# [31]	train-rmse:0.31392	val-rmse:0.43782
# [32]	train-rmse:0.31263	val-rmse:0.43761
# [33]	train-rmse:0.31155	val-rmse:0.43764
# [34]	train-rmse:0.31054	val-rmse:0.43793
# [35]	train-rmse:0.30960	val-rmse:0.43784
# [36]	train-rmse:0.30813	val-rmse:0.43828
# [37]	train-rmse:0.30573	val-rmse:0.43891
# [38]	train-rmse:0.30406	val-rmse:0.43924
# [39]	train-rmse:0.30257	val-rmse:0.43946
# [40]	train-rmse:0.30202	val-rmse:0.43968
# [41]	train-rmse:0.29908	val-rmse:0.43978
# [42]	train-rmse:0.29772	val-rmse:0.43998
# [43]	train-rmse:0.29594	val-rmse:0.43969
# [44]	train-rmse:0.29420	val-rmse:0.44009
# [45]	train-rmse:0.29126	val-rmse:0.44024
# [46]	train-rmse:0.28929	val-rmse:0.44041
# [47]	train-rmse:0.28821	val-rmse:0.44101
# [48]	train-rmse:0.28629	val-rmse:0.44096
# [49]	train-rmse:0.28528	val-rmse:0.44142
# [50]	train-rmse:0.28456	val-rmse:0.44140
# [51]	train-rmse:0.28309	val-rmse:0.44160
# [52]	train-rmse:0.28144	val-rmse:0.44109
# [53]	train-rmse:0.28095	val-rmse:0.44152
# [54]	train-rmse:0.27894	val-rmse:0.44191
# [55]	train-rmse:0.27618	val-rmse:0.44225
# [56]	train-rmse:0.27373	val-rmse:0.44265
# [57]	train-rmse:0.27156	val-rmse:0.44310
# [58]	train-rmse:0.26938	val-rmse:0.44276
# [59]	train-rmse:0.26797	val-rmse:0.44282
# [60]	train-rmse:0.26768	val-rmse:0.44290
# [61]	train-rmse:0.26749	val-rmse:0.44285
# [62]	train-rmse:0.26536	val-rmse:0.44311
# [63]	train-rmse:0.26420	val-rmse:0.44329
# [64]	train-rmse:0.26236	val-rmse:0.44360
# [65]	train-rmse:0.26174	val-rmse:0.44352
# [66]	train-rmse:0.26155	val-rmse:0.44360
# [67]	train-rmse:0.25959	val-rmse:0.44410
# [68]	train-rmse:0.25719	val-rmse:0.44487
# [69]	train-rmse:0.25665	val-rmse:0.44476
# [70]	train-rmse:0.25489	val-rmse:0.44531
# [71]	train-rmse:0.25277	val-rmse:0.44563
# [72]	train-rmse:0.25084	val-rmse:0.44632
# [73]	train-rmse:0.25017	val-rmse:0.44649
# [74]	train-rmse:0.24985	val-rmse:0.44661
# [75]	train-rmse:0.24792	val-rmse:0.44628
# [76]	train-rmse:0.24643	val-rmse:0.44671
# [77]	train-rmse:0.24565	val-rmse:0.44667
# [78]	train-rmse:0.24421	val-rmse:0.44633
# [79]	train-rmse:0.24291	val-rmse:0.44663
# [80]	train-rmse:0.24254	val-rmse:0.44689
# [81]	train-rmse:0.24246	val-rmse:0.44692
# [82]	train-rmse:0.24112	val-rmse:0.44705
# [83]	train-rmse:0.23963	val-rmse:0.44721
# [84]	train-rmse:0.23803	val-rmse:0.44704
# [85]	train-rmse:0.23644	val-rmse:0.44749
# [86]	train-rmse:0.23533	val-rmse:0.44757
# [87]	train-rmse:0.23481	val-rmse:0.44756
# [88]	train-rmse:0.23428	val-rmse:0.44778
# [89]	train-rmse:0.23267	val-rmse:0.44809
# [90]	train-rmse:0.23193	val-rmse:0.44839
# [91]	train-rmse:0.23149	val-rmse:0.44844
# [92]	train-rmse:0.23040	val-rmse:0.44863
# [93]	train-rmse:0.22891	val-rmse:0.44896
# [94]	train-rmse:0.22701	val-rmse:0.44922
# [95]	train-rmse:0.22475	val-rmse:0.44904
# [96]	train-rmse:0.22336	val-rmse:0.44954
# [97]	train-rmse:0.22131	val-rmse:0.44979
# [98]	train-rmse:0.22013	val-rmse:0.45040
# [99]	train-rmse:0.21950	val-rmse:0.45018
# [100]	train-rmse:0.21754	val-rmse:0.45039
# [101]	train-rmse:0.21626	val-rmse:0.45036
# [102]	train-rmse:0.21510	val-rmse:0.45060
# [103]	train-rmse:0.21409	val-rmse:0.45063
# [104]	train-rmse:0.21399	val-rmse:0.45070
# [105]	train-rmse:0.21323	val-rmse:0.45075
# [106]	train-rmse:0.21276	val-rmse:0.45107
# [107]	train-rmse:0.21165	val-rmse:0.45115
# [108]	train-rmse:0.21020	val-rmse:0.45142
# [109]	train-rmse:0.20885	val-rmse:0.45149
# [110]	train-rmse:0.20766	val-rmse:0.45166
# [111]	train-rmse:0.20687	val-rmse:0.45170
# [112]	train-rmse:0.20547	val-rmse:0.45167
# [113]	train-rmse:0.20422	val-rmse:0.45227
# [114]	train-rmse:0.20299	val-rmse:0.45253
# [115]	train-rmse:0.20189	val-rmse:0.45237
# [116]	train-rmse:0.20118	val-rmse:0.45262
# [117]	train-rmse:0.19954	val-rmse:0.45287
# [118]	train-rmse:0.19941	val-rmse:0.45298
# [119]	train-rmse:0.19755	val-rmse:0.45332
# [120]	train-rmse:0.19643	val-rmse:0.45317
# [121]	train-rmse:0.19530	val-rmse:0.45338
# [122]	train-rmse:0.19374	val-rmse:0.45341
# [123]	train-rmse:0.19175	val-rmse:0.45350
# [124]	train-rmse:0.19130	val-rmse:0.45346
# [125]	train-rmse:0.18980	val-rmse:0.45366
# [126]	train-rmse:0.18882	val-rmse:0.45383
# [127]	train-rmse:0.18741	val-rmse:0.45430
# [128]	train-rmse:0.18615	val-rmse:0.45457
# [129]	train-rmse:0.18572	val-rmse:0.45460
# [130]	train-rmse:0.18527	val-rmse:0.45478
# [131]	train-rmse:0.18401	val-rmse:0.45456
# [132]	train-rmse:0.18391	val-rmse:0.45455
# [133]	train-rmse:0.18229	val-rmse:0.45434
# [134]	train-rmse:0.18087	val-rmse:0.45458
# [135]	train-rmse:0.18040	val-rmse:0.45477
# [136]	train-rmse:0.18032	val-rmse:0.45481
# [137]	train-rmse:0.17889	val-rmse:0.45482
# [138]	train-rmse:0.17770	val-rmse:0.45522
# [139]	train-rmse:0.17651	val-rmse:0.45562
# [140]	train-rmse:0.17645	val-rmse:0.45571
# [141]	train-rmse:0.17563	val-rmse:0.45567
# [142]	train-rmse:0.17505	val-rmse:0.45546
# [143]	train-rmse:0.17447	val-rmse:0.45583
# [144]	train-rmse:0.17433	val-rmse:0.45586
# [145]	train-rmse:0.17246	val-rmse:0.45611
# [146]	train-rmse:0.17149	val-rmse:0.45637
# [147]	train-rmse:0.17140	val-rmse:0.45644
# [148]	train-rmse:0.17010	val-rmse:0.45659
# [149]	train-rmse:0.16958	val-rmse:0.45664
# [150]	train-rmse:0.16879	val-rmse:0.45677
# [151]	train-rmse:0.16763	val-rmse:0.45678
# [152]	train-rmse:0.16708	val-rmse:0.45670
# [153]	train-rmse:0.16559	val-rmse:0.45687
# [154]	train-rmse:0.16507	val-rmse:0.45708
# [155]	train-rmse:0.16463	val-rmse:0.45718
# [156]	train-rmse:0.16416	val-rmse:0.45702
# [157]	train-rmse:0.16345	val-rmse:0.45714
# [158]	train-rmse:0.16251	val-rmse:0.45725
# [159]	train-rmse:0.16194	val-rmse:0.45741
# [160]	train-rmse:0.16091	val-rmse:0.45742
# [161]	train-rmse:0.15974	val-rmse:0.45768
# [162]	train-rmse:0.15924	val-rmse:0.45775
# [163]	train-rmse:0.15853	val-rmse:0.45774
# [164]	train-rmse:0.15791	val-rmse:0.45796
# [165]	train-rmse:0.15692	val-rmse:0.45779
# [166]	train-rmse:0.15594	val-rmse:0.45800
# [167]	train-rmse:0.15527	val-rmse:0.45833
# [168]	train-rmse:0.15425	val-rmse:0.45825
# [169]	train-rmse:0.15283	val-rmse:0.45836
# [170]	train-rmse:0.15213	val-rmse:0.45809
# [171]	train-rmse:0.15099	val-rmse:0.45835
# [172]	train-rmse:0.14974	val-rmse:0.45860
# [173]	train-rmse:0.14878	val-rmse:0.45895
# [174]	train-rmse:0.14733	val-rmse:0.45888
# [175]	train-rmse:0.14595	val-rmse:0.45896
# [176]	train-rmse:0.14478	val-rmse:0.45921
# [177]	train-rmse:0.14391	val-rmse:0.45925
# [178]	train-rmse:0.14313	val-rmse:0.45943
# [179]	train-rmse:0.14204	val-rmse:0.45957
# [180]	train-rmse:0.14118	val-rmse:0.45971
# [181]	train-rmse:0.14115	val-rmse:0.45972
# [182]	train-rmse:0.14031	val-rmse:0.45996
# [183]	train-rmse:0.13930	val-rmse:0.46014
# [184]	train-rmse:0.13883	val-rmse:0.46018
# [185]	train-rmse:0.13824	val-rmse:0.46018
# [186]	train-rmse:0.13818	val-rmse:0.46018
# [187]	train-rmse:0.13727	val-rmse:0.46039
# [188]	train-rmse:0.13704	val-rmse:0.46057
# [189]	train-rmse:0.13616	val-rmse:0.46085
# [190]	train-rmse:0.13535	val-rmse:0.46078
# [191]	train-rmse:0.13442	val-rmse:0.46086
# [192]	train-rmse:0.13392	val-rmse:0.46101
# [193]	train-rmse:0.13288	val-rmse:0.46111
# [194]	train-rmse:0.13246	val-rmse:0.46121
# [195]	train-rmse:0.13149	val-rmse:0.46140
# [196]	train-rmse:0.13058	val-rmse:0.46163
# [197]	train-rmse:0.12975	val-rmse:0.46175
# [198]	train-rmse:0.12883	val-rmse:0.46171
# [199]	train-rmse:0.12780	val-rmse:0.46203

# %%
from sklearn.metrics import root_mean_squared_error

# %%
y_pred = model.predict(dval)
rmse = root_mean_squared_error(y_val, y_pred)
rmse
# Out:
# 0.46203156380184496

# %%
xgb_params = {
    'eta': 0.1,
    'max_depth': 6,
    'min_child_weight': 1,

    'objective': 'reg:squarederror',
    'nthread': 24,

    'seed': 1,
    'verbosity': 1,
}

model = xgb.train(params=xgb_params, dtrain=dtrain, num_boost_round=200,
                         evals=watchlist)
# Out:
# [0]	train-rmse:2.28944	val-rmse:2.34561
# [1]	train-rmse:2.07396	val-rmse:2.12434
# [2]	train-rmse:1.88066	val-rmse:1.92597
# [3]	train-rmse:1.70730	val-rmse:1.74987
# [4]	train-rmse:1.55163	val-rmse:1.59059
# [5]	train-rmse:1.41247	val-rmse:1.44988
# [6]	train-rmse:1.28796	val-rmse:1.32329
# [7]	train-rmse:1.17660	val-rmse:1.20930
# [8]	train-rmse:1.07736	val-rmse:1.10830
# [9]	train-rmse:0.98883	val-rmse:1.02009
# [10]	train-rmse:0.91008	val-rmse:0.94062
# [11]	train-rmse:0.84030	val-rmse:0.87100
# [12]	train-rmse:0.77874	val-rmse:0.80916
# [13]	train-rmse:0.72417	val-rmse:0.75465
# [14]	train-rmse:0.67626	val-rmse:0.70780
# [15]	train-rmse:0.63402	val-rmse:0.66672
# [16]	train-rmse:0.59690	val-rmse:0.63062
# [17]	train-rmse:0.56447	val-rmse:0.60016
# [18]	train-rmse:0.53619	val-rmse:0.57383
# [19]	train-rmse:0.51138	val-rmse:0.55044
# [20]	train-rmse:0.48983	val-rmse:0.53064
# [21]	train-rmse:0.47135	val-rmse:0.51451
# [22]	train-rmse:0.45501	val-rmse:0.49998
# [23]	train-rmse:0.44120	val-rmse:0.48790
# [24]	train-rmse:0.42929	val-rmse:0.47773
# [25]	train-rmse:0.41881	val-rmse:0.46891
# [26]	train-rmse:0.40953	val-rmse:0.46151
# [27]	train-rmse:0.40173	val-rmse:0.45551
# [28]	train-rmse:0.39470	val-rmse:0.45043
# [29]	train-rmse:0.38873	val-rmse:0.44621
# [30]	train-rmse:0.38342	val-rmse:0.44289
# [31]	train-rmse:0.37876	val-rmse:0.43989
# [32]	train-rmse:0.37450	val-rmse:0.43754
# [33]	train-rmse:0.37073	val-rmse:0.43553
# [34]	train-rmse:0.36743	val-rmse:0.43390
# [35]	train-rmse:0.36435	val-rmse:0.43250
# [36]	train-rmse:0.36178	val-rmse:0.43095
# [37]	train-rmse:0.35927	val-rmse:0.42976
# [38]	train-rmse:0.35713	val-rmse:0.42866
# [39]	train-rmse:0.35506	val-rmse:0.42806
# [40]	train-rmse:0.35343	val-rmse:0.42746
# [41]	train-rmse:0.35195	val-rmse:0.42692
# [42]	train-rmse:0.35024	val-rmse:0.42666
# [43]	train-rmse:0.34862	val-rmse:0.42616
# [44]	train-rmse:0.34714	val-rmse:0.42613
# [45]	train-rmse:0.34621	val-rmse:0.42595
# [46]	train-rmse:0.34477	val-rmse:0.42563
# [47]	train-rmse:0.34342	val-rmse:0.42548
# [48]	train-rmse:0.34217	val-rmse:0.42520
# [49]	train-rmse:0.34097	val-rmse:0.42513
# [50]	train-rmse:0.33998	val-rmse:0.42498
# [51]	train-rmse:0.33860	val-rmse:0.42481
# [52]	train-rmse:0.33767	val-rmse:0.42453
# [53]	train-rmse:0.33651	val-rmse:0.42459
# [54]	train-rmse:0.33560	val-rmse:0.42448
# [55]	train-rmse:0.33480	val-rmse:0.42449
# [56]	train-rmse:0.33386	val-rmse:0.42426
# [57]	train-rmse:0.33292	val-rmse:0.42429
# [58]	train-rmse:0.33196	val-rmse:0.42438
# [59]	train-rmse:0.33105	val-rmse:0.42450
# [60]	train-rmse:0.33054	val-rmse:0.42456
# [61]	train-rmse:0.32953	val-rmse:0.42444
# [62]	train-rmse:0.32872	val-rmse:0.42454
# [63]	train-rmse:0.32777	val-rmse:0.42461
# [64]	train-rmse:0.32673	val-rmse:0.42479
# [65]	train-rmse:0.32602	val-rmse:0.42493
# [66]	train-rmse:0.32489	val-rmse:0.42520
# [67]	train-rmse:0.32397	val-rmse:0.42525
# [68]	train-rmse:0.32338	val-rmse:0.42518
# [69]	train-rmse:0.32275	val-rmse:0.42513
# [70]	train-rmse:0.32202	val-rmse:0.42503
# [71]	train-rmse:0.32161	val-rmse:0.42515
# [72]	train-rmse:0.32060	val-rmse:0.42496
# [73]	train-rmse:0.31996	val-rmse:0.42517
# [74]	train-rmse:0.31963	val-rmse:0.42513
# [75]	train-rmse:0.31895	val-rmse:0.42526
# [76]	train-rmse:0.31825	val-rmse:0.42538
# [77]	train-rmse:0.31755	val-rmse:0.42559
# [78]	train-rmse:0.31742	val-rmse:0.42568
# [79]	train-rmse:0.31702	val-rmse:0.42568
# [80]	train-rmse:0.31667	val-rmse:0.42563
# [81]	train-rmse:0.31656	val-rmse:0.42571
# [82]	train-rmse:0.31569	val-rmse:0.42564
# [83]	train-rmse:0.31547	val-rmse:0.42568
# [84]	train-rmse:0.31475	val-rmse:0.42581
# [85]	train-rmse:0.31440	val-rmse:0.42574
# [86]	train-rmse:0.31352	val-rmse:0.42579
# [87]	train-rmse:0.31285	val-rmse:0.42576
# [88]	train-rmse:0.31243	val-rmse:0.42586
# [89]	train-rmse:0.31146	val-rmse:0.42574
# [90]	train-rmse:0.31059	val-rmse:0.42586
# [91]	train-rmse:0.30997	val-rmse:0.42591
# [92]	train-rmse:0.30943	val-rmse:0.42590
# [93]	train-rmse:0.30817	val-rmse:0.42591
# [94]	train-rmse:0.30699	val-rmse:0.42622
# [95]	train-rmse:0.30625	val-rmse:0.42611
# [96]	train-rmse:0.30565	val-rmse:0.42621
# [97]	train-rmse:0.30557	val-rmse:0.42629
# [98]	train-rmse:0.30486	val-rmse:0.42629
# [99]	train-rmse:0.30419	val-rmse:0.42623
# [100]	train-rmse:0.30364	val-rmse:0.42635
# [101]	train-rmse:0.30321	val-rmse:0.42640
# [102]	train-rmse:0.30290	val-rmse:0.42655
# [103]	train-rmse:0.30264	val-rmse:0.42661
# [104]	train-rmse:0.30166	val-rmse:0.42679
# [105]	train-rmse:0.30092	val-rmse:0.42694
# [106]	train-rmse:0.30014	val-rmse:0.42696
# [107]	train-rmse:0.29957	val-rmse:0.42689
# [108]	train-rmse:0.29904	val-rmse:0.42697
# [109]	train-rmse:0.29872	val-rmse:0.42718
# [110]	train-rmse:0.29764	val-rmse:0.42721
# [111]	train-rmse:0.29728	val-rmse:0.42724
# [112]	train-rmse:0.29643	val-rmse:0.42719
# [113]	train-rmse:0.29596	val-rmse:0.42723
# [114]	train-rmse:0.29573	val-rmse:0.42725
# [115]	train-rmse:0.29561	val-rmse:0.42721
# [116]	train-rmse:0.29472	val-rmse:0.42711
# [117]	train-rmse:0.29419	val-rmse:0.42715
# [118]	train-rmse:0.29408	val-rmse:0.42711
# [119]	train-rmse:0.29362	val-rmse:0.42725
# [120]	train-rmse:0.29287	val-rmse:0.42730
# [121]	train-rmse:0.29256	val-rmse:0.42738
# [122]	train-rmse:0.29170	val-rmse:0.42735
# [123]	train-rmse:0.29065	val-rmse:0.42713
# [124]	train-rmse:0.29055	val-rmse:0.42711
# [125]	train-rmse:0.29012	val-rmse:0.42718
# [126]	train-rmse:0.28992	val-rmse:0.42732
# [127]	train-rmse:0.28909	val-rmse:0.42741
# [128]	train-rmse:0.28822	val-rmse:0.42751
# [129]	train-rmse:0.28773	val-rmse:0.42749
# [130]	train-rmse:0.28734	val-rmse:0.42757
# [131]	train-rmse:0.28648	val-rmse:0.42776
# [132]	train-rmse:0.28567	val-rmse:0.42782
# [133]	train-rmse:0.28523	val-rmse:0.42788
# [134]	train-rmse:0.28484	val-rmse:0.42800
# [135]	train-rmse:0.28475	val-rmse:0.42805
# [136]	train-rmse:0.28441	val-rmse:0.42819
# [137]	train-rmse:0.28398	val-rmse:0.42824
# [138]	train-rmse:0.28323	val-rmse:0.42822
# [139]	train-rmse:0.28233	val-rmse:0.42814
# [140]	train-rmse:0.28202	val-rmse:0.42823
# [141]	train-rmse:0.28126	val-rmse:0.42829
# [142]	train-rmse:0.28097	val-rmse:0.42837
# [143]	train-rmse:0.28090	val-rmse:0.42844
# [144]	train-rmse:0.28029	val-rmse:0.42838
# [145]	train-rmse:0.28024	val-rmse:0.42838
# [146]	train-rmse:0.28011	val-rmse:0.42849
# [147]	train-rmse:0.28001	val-rmse:0.42849
# [148]	train-rmse:0.27923	val-rmse:0.42847
# [149]	train-rmse:0.27894	val-rmse:0.42855
# [150]	train-rmse:0.27820	val-rmse:0.42858
# [151]	train-rmse:0.27788	val-rmse:0.42858
# [152]	train-rmse:0.27770	val-rmse:0.42859
# [153]	train-rmse:0.27766	val-rmse:0.42864
# [154]	train-rmse:0.27765	val-rmse:0.42865
# [155]	train-rmse:0.27683	val-rmse:0.42861
# [156]	train-rmse:0.27625	val-rmse:0.42867
# [157]	train-rmse:0.27563	val-rmse:0.42882
# [158]	train-rmse:0.27483	val-rmse:0.42883
# [159]	train-rmse:0.27475	val-rmse:0.42884
# [160]	train-rmse:0.27405	val-rmse:0.42890
# [161]	train-rmse:0.27334	val-rmse:0.42892
# [162]	train-rmse:0.27260	val-rmse:0.42889
# [163]	train-rmse:0.27174	val-rmse:0.42901
# [164]	train-rmse:0.27107	val-rmse:0.42915
# [165]	train-rmse:0.27020	val-rmse:0.42944
# [166]	train-rmse:0.26960	val-rmse:0.42958
# [167]	train-rmse:0.26906	val-rmse:0.42964
# [168]	train-rmse:0.26878	val-rmse:0.42972
# [169]	train-rmse:0.26820	val-rmse:0.42970
# [170]	train-rmse:0.26716	val-rmse:0.42971
# [171]	train-rmse:0.26640	val-rmse:0.42987
# [172]	train-rmse:0.26598	val-rmse:0.42986
# [173]	train-rmse:0.26581	val-rmse:0.42994
# [174]	train-rmse:0.26566	val-rmse:0.43000
# [175]	train-rmse:0.26524	val-rmse:0.43014
# [176]	train-rmse:0.26520	val-rmse:0.43019
# [177]	train-rmse:0.26510	val-rmse:0.43026
# [178]	train-rmse:0.26495	val-rmse:0.43029
# [179]	train-rmse:0.26436	val-rmse:0.43041
# [180]	train-rmse:0.26373	val-rmse:0.43045
# [181]	train-rmse:0.26323	val-rmse:0.43048
# [182]	train-rmse:0.26251	val-rmse:0.43056
# [183]	train-rmse:0.26152	val-rmse:0.43058
# [184]	train-rmse:0.26105	val-rmse:0.43052
# [185]	train-rmse:0.26061	val-rmse:0.43053
# [186]	train-rmse:0.26004	val-rmse:0.43057
# [187]	train-rmse:0.25963	val-rmse:0.43060
# [188]	train-rmse:0.25925	val-rmse:0.43089
# [189]	train-rmse:0.25911	val-rmse:0.43094
# [190]	train-rmse:0.25842	val-rmse:0.43084
# [191]	train-rmse:0.25803	val-rmse:0.43083
# [192]	train-rmse:0.25768	val-rmse:0.43097
# [193]	train-rmse:0.25748	val-rmse:0.43100
# [194]	train-rmse:0.25732	val-rmse:0.43105
# [195]	train-rmse:0.25666	val-rmse:0.43129
# [196]	train-rmse:0.25594	val-rmse:0.43123
# [197]	train-rmse:0.25553	val-rmse:0.43139
# [198]	train-rmse:0.25505	val-rmse:0.43140
# [199]	train-rmse:0.25475	val-rmse:0.43152

# %%
y_pred = model.predict(dval)
rmse = root_mean_squared_error(y_val, y_pred)
rmse
# Out:
# 0.43151829815693454

# %% [markdown]
# ### With eta set to 0.1 the results are better

# %% [markdown]
# ## Submit the results
#
# * Submit your results here: https://courses.datatalks.club/ml-zoomcamp-2025/homework/hw06
# * If your answer doesn't match options exactly, select the closest one. If the answer is exactly in between two options, select the higher value.
